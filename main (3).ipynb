# %% [markdown]
# # Modelo de Examen Practico - TLP3 - Python para Ciencia de Datos.

# %% [markdown]
# **A partir del datasets brindado, realizar los siguientes procedimientos:**
#
# * Importar datasets con Pandas.
# * Explorar los datos con los metodos correspondientes.
# * Limpieza de los datos (Normalización de datos).
# * Obtener estadisticas.
# * Mostrar los datos procesados con graficos utilizando la libreria Matplotlib.
# * Exportar el contenido a un archivo sqlite utilizando PANDAS.
#
#
# **Importante: Se debe documentar cada procedimiento realizado, siguiendo la siguiente estructura:**
#
# 1. Celda de Markdown (Documentación)
# 2. Código (Sin comentarios, se debe documentar lo sufiente solo en la celda de markdown).

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.2.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-2.2.5-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install Matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.57.0-cp312-cp312-win_amd64.whl.metadata (104 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached matplotlib-3.10.1-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl (223 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.57.0-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Using cached pillow-11.2.1-cp312-cp312-win_amd64.whl (2.7 MB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# ...

# %% [markdown]
# ## Actividades:
# ### 1. Importación del Dataset con Pandas
#
# En esta sección, se debe utilizar la librería Pandas para cargar el archivo CSV que contiene los datos de las calificaciones en un DataFrame, que es la estructura de datos fundamental para el análisis con Pandas.
#
# ### 2. Exploración Inicial de los Datos
#
# A continuación, se deben emplear métodos de Pandas para obtener una visión general del dataset. Esto incluye mostrar las primeras filas, obtener un resumen de la información del DataFrame (tipos de datos, valores no nulos), y calcular estadísticas descriptivas de las columnas numéricas.
#
# ### 3. Limpieza y Normalización de los Datos
#
# Esta etapa crucial deben aplicar la corrección de diversos errores presentes en el dataset. Se abordarán los valores faltantes, la inconsistencia en el formato de la columna 'Asistencia', los posibles valores atípicos y la normalización de los nombres de estudiantes y materias a un formato consistente (por ejemplo, capitalización).
#
# ### 4. Obtención de Estadísticas Descriptivas
#
# Después de la limpieza, deben calcular nuevamente las estadísticas descriptivas para observar el impacto del proceso de limpieza en los datos numéricos. También se pueden calcular estadísticas específicas por grupo (por ejemplo, promedio de calificaciones por materia).
#
# ### 5. Visualización de los Datos con Matplotlib
#
# En esta sección, deben utilizar la librería Matplotlib para crear visualizaciones que permitan comprender mejor la distribución de las calificaciones y la asistencia. Se generarán histogramas, diagramas de dispersión y gráficos de barras.
#
# ### 6. Exportación a Archivo SQLite
#
# Finalmente, deben utilizar la funcionalidad de Pandas para guardar el DataFrame procesado en una base de datos SQLite. Esto permite almacenar los datos de forma estructurada para su posterior consulta y uso.

# %% [markdown]
# ## Punto 1:
# Se importa la libreria pandas, luego se carga el archivo csv que contiene los datos de las calificaciones en un DataFrame

# %%
import pandas as pd
df = pd.read_csv("datasets_calificaciones.csv", on_bad_lines="skip")

# %% [markdown]
# ## Punto 2: exploracion inicial de los datos
# Se utilizia el metodo head() para mostrar las primeras filas del DataFrame
# Se utiliza el metodo info() para obtener tipos de datos y valores no nulos
# Se utiliza el metodo describe() para obtener un analisis estadistico de las columnas

# %%
df.head(20)
# Out:
#           estudiante               Materia Parcial 1 Parcial 2 Final  \
# 0          ana pérez           matematicas         8       7.5     9
# 1       carlos lópez                fisica       6.2         7   NaN
# 2        maría gómez               quimica         9       8.8   9.5
# 3    pedro rodríguez              historia       7.5         6     7
# 4       laura vargas           matematicas                 9.2   8.5
# 5        javier soto                fisica       5.8       6.5     6
# 6         sofia díaz     ciencias sociales       9.5       9.1
# 7   miguel fernández  literatura universal         8       7.8   8.2
# 8     valentina ruiz           matematicas         7             7.8
# 9       diego castro                fisica       6.8       7.2   7.5
# 10   isabella torres               quimica       9.2       8.5     9
# 11  sebastián vargas              historia       7.9       6.3
# 12      martina soto           matematicas       8.5       8.9   9.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   estudiante  100 non-null    object
#  1   Materia     100 non-null    object
#  2   Parcial 1   95 non-null     object
#  3   Parcial 2   90 non-null     object
#  4   Final       89 non-null     object
#  5   Asistencia  100 non-null    object
# dtypes: object(6)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#         estudiante      Materia Parcial 1 Parcial 2 Final Asistencia
# count          100          100        95        90    89        100
# unique          96            7        49        45    46         35
# top     mateo díaz  matematicas                 7.5   9.5        99%
# freq             2           25         7         5     4          5

# %% [markdown]
# ## Punto 3: Limpieza y Normalización de los Datos
# - Se utiliza isnull().sum() para contar cuantos valores nulos hay por columna
# - Se utiliza .replace("[\%,]", "", regex=True) para eliminar simbolos y luego convertirlo a tipo numerico
# - Se utiliza to_numeric([]) para convertir parcial 1, parcial 2, final y asistencia a tipo numerico
# - Se utiliza df.info() para corroborar que se hayan convertido a tipo numerico esas columnas
# - Se utiliza .fillna() para reemplazar los NaN y luego .mean() para sacar el promedio de esas columnas y inplace=True para que modifique el dataframe original sin reasignar a una nueva variable
# - Se utiliza .str.title().str.strip() para corregir la capitalizacion y eliminar espacios extra
# - Se utiliza .loc para ver errores atipicos y luego reemplazarlos

# %%
df.isnull().sum()
# Out:
# estudiante     0
# Materia        0
# Parcial 1      5
# Parcial 2     10
# Final         11
# Asistencia     0
# dtype: int64

# %%
df["Parcial 1"] = pd.to_numeric(df["Parcial 1"], errors = "coerce")
df["Parcial 2"] = pd.to_numeric(df["Parcial 2"], errors = "coerce")
df["Final"] = pd.to_numeric(df["Final"], errors = "coerce")
df["Asistencia"] = df["Asistencia"].replace("[\%,]", "", regex=True)
df["Asistencia"] = pd.to_numeric(df["Asistencia"], errors = "coerce")
df.head(20)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\%'
# <>:4: SyntaxWarning: invalid escape sequence '\%'
# C:\Users\IPF-2025\AppData\Local\Temp\ipykernel_16488\1886734499.py:4: SyntaxWarning: invalid escape sequence '\%'
#   df["Asistencia"] = df["Asistencia"].replace("[\%,]", "", regex=True)
#           estudiante               Materia  Parcial 1  Parcial 2  Final  \
# 0          ana pérez           matematicas        8.0        7.5    9.0
# 1       carlos lópez                fisica        6.2        7.0    NaN
# 2        maría gómez               quimica        9.0        8.8    9.5
# 3    pedro rodríguez              historia        7.5        6.0    7.0
# 4       laura vargas           matematicas        NaN        9.2    8.5
# 5        javier soto                fisica        5.8        6.5    6.0
# 6         sofia díaz     ciencias sociales        9.5        9.1    NaN
# 7   miguel fernández  literatura universal        8.0        7.8    8.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   estudiante  100 non-null    object
#  1   Materia     100 non-null    object
#  2   Parcial 1   88 non-null     float64
#  3   Parcial 2   88 non-null     float64
#  4   Final       85 non-null     float64
#  5   Asistencia  100 non-null    int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 4.8+ KB

# %%
df["Parcial 1"].fillna(df["Parcial 1"].mean().round(2), inplace=True)
df["Parcial 2"].fillna(df["Parcial 2"].mean().round(2), inplace=True)
df["Final"].fillna(df["Final"].mean().round(2), inplace=True)
df.head(20)
# Out:
# C:\Users\IPF-2025\AppData\Local\Temp\ipykernel_16488\1556666061.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Parcial 1"].fillna(df["Parcial 1"].mean().round(2), inplace=True)
# C:\Users\IPF-2025\AppData\Local\Temp\ipykernel_16488\1556666061.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df["estudiante"] = df["estudiante"].astype(str).str.title().str.strip()
df["Materia"] = df["Materia"].astype(str).str.title().str.strip()
df.head(20)
# Out:
#           estudiante               Materia  Parcial 1  Parcial 2  Final  \
# 0          Ana Pérez           Matematicas       8.00       7.50   9.00
# 1       Carlos López                Fisica       6.20       7.00   7.89
# 2        María Gómez               Quimica       9.00       8.80   9.50
# 3    Pedro Rodríguez              Historia       7.50       6.00   7.00
# 4       Laura Vargas           Matematicas       7.83       9.20   8.50
# 5        Javier Soto                Fisica       5.80       6.50   6.00
# 6         Sofia Díaz     Ciencias Sociales       9.50       9.10   7.89
# 7   Miguel Fernández  Literatura Universal       8.00       7.80   8.20
# 8     Valentina Ruiz           Matematicas       7.00       7.83   7.80
# 9       Diego Castro                Fisica       6.80       7.20   7.50
# 10   Isabella Torres               Quimica       9.20       8.50   9.00
# 11  Sebastián Vargas              Historia       7.90       6.30   7.89
# ...

# %%
df[df["Asistencia"] > 100]
df.loc[df["Asistencia"] > 100, "Asistencia"] = 100
df.head(20)
# Out:
#           estudiante               Materia  Parcial 1  Parcial 2  Final  \
# 0          Ana Pérez           Matematicas       8.00       7.50   9.00
# 1       Carlos López                Fisica       6.20       7.00   7.89
# 2        María Gómez               Quimica       9.00       8.80   9.50
# 3    Pedro Rodríguez              Historia       7.50       6.00   7.00
# 4       Laura Vargas           Matematicas       7.83       9.20   8.50
# 5        Javier Soto                Fisica       5.80       6.50   6.00
# 6         Sofia Díaz     Ciencias Sociales       9.50       9.10   7.89
# 7   Miguel Fernández  Literatura Universal       8.00       7.80   8.20
# 8     Valentina Ruiz           Matematicas       7.00       7.83   7.80
# 9       Diego Castro                Fisica       6.80       7.20   7.50
# 10   Isabella Torres               Quimica       9.20       8.50   9.00
# 11  Sebastián Vargas              Historia       7.90       6.30   7.89
# ...

# %% [markdown]
# ## Punto 4: Obtencion de estadisticas descriptivas
# - Se utiliza df.describe() para obtener las estadisticas basicas de las columnas numericas
# - Se utiliza groupby para agrupar la columna Materia y luego mostrar el promedio con .mean() de la columna Final y Asistencia

# %%
df.describe()
# Out:
#         Parcial 1  Parcial 2       Final  Asistencia
# count  100.000000  100.00000  100.000000  100.000000
# mean     7.831600    7.83060    7.893500   88.180000
# std      1.134184    1.10895    1.111134    8.445165
# min      5.500000    5.80000    5.700000   70.000000
# 25%      7.075000    6.97500    7.100000   81.750000
# 50%      7.830000    7.83000    7.890000   88.500000
# 75%      8.800000    8.80000    8.825000   96.000000
# max      9.900000    9.90000    9.900000  100.000000

# %%
df.groupby("Materia")["Final"].mean().round(2)
# Out:
# Materia
# Ciencias Sociales       7.89
# Fisica                  6.62
# Historia                7.48
# Literatura Universal    8.20
# Matematicas             8.47
# Programacion Basica     6.30
# Quimica                 9.03
# Name: Final, dtype: float64

# %%
df.groupby("Materia")["Asistencia"].mean().round(2)
# Out:
# Materia
# Ciencias Sociales       98.00
# Fisica                  82.21
# Historia                80.08
# Literatura Universal    85.00
# Matematicas             92.68
# Programacion Basica     82.00
# Quimica                 97.54
# Name: Asistencia, dtype: float64

# %% [markdown]
# ## Punto 5: visualizacion de los datos con Matplotlib
# - Se importa la libreria matplotlib, la herramienta pyplot y se le asigna el alias plt para generar graficos
# - Se creo un histograma para representar la distribucion de la asistencia de los estudiantes
# - Se creo un grafico de dispersion para ver la relacion entre Parcial 1 vs Parcial 2 de los estudiantes
# - Se creo un grafico de barras para representar el promedio de nota final por materia de los estudiantes

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,5))
plt.hist(df["Asistencia"], color="skyblue", edgecolor="gray")
plt.title("Distribucion de la asistencia de estudiantes")
plt.xlabel("Asistencia %")
plt.ylabel("Cantidad de estudiantes")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.scatter(df["Parcial 1"], df["Parcial 2"])
plt.title("Relacion Parcial 1 vs Parcial 2")
plt.xlabel("Parcial 1")
plt.ylabel("Parcial 2")
plt.grid(True)
plt.show()

# %%
promedios_materia = df.groupby("Materia")["Final"].mean()
promedios_materia.plot(kind="bar", color="pink", edgecolor="gray")
plt.title("Promedio de nota final por materia")
plt.xlabel("Materia")
plt.ylabel("Nota Final")
plt.xticks(rotation=45)
plt.grid(axis="y")
plt.show()

# %% [markdown]
# ## Punto 6: Exportacion a archivo sqlite
# - se importa la libreria sqlite3
# - se crea una conexion a una base de datos nueva con el nombre "calificaciones.db"
# - se guarda el dataframe en una tabla de la base de datos llamada "calificaciones_estudiantes"
# - se cierra la conexion

# %%
import sqlite3
conn = sqlite3.connect("calificaciones.db")
df.to_sql("calificaciones_estudiantes", conn, index=False)
conn.close()
